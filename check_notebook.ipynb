# %% [markdown]
# # Setup check — the notebook half
#
# The command-line check proved that `uv sync` and `uv run` work. This notebook proves that VS Code can **execute cells** on this project's environment, which is what every lab needs.
#
# 1. Click **Select Kernel** (top right) → **Python Environments…** → the entry marked *Recommended* whose path contains **`.venv`**.
# 2. **Run All** (the ▷▷ button above, or *Run → Run All*).
# 3. Three lines of output should appear below the three cells: a path that contains `.venv`, a pandas version, and this folder.
#
# Screenshot the three outputs and submit them together with the command-line report.

# %%
import sys
print(sys.executable)   # must contain .venv — otherwise you picked another Python

# %%
import pandas as pd
print("pandas", pd.__version__)   # ModuleNotFoundError here = wrong kernel, same cause

# %%
import os
print(os.getcwd())   # the folder you cloned; Session 1 explains why this line matters

# %% [markdown]
# If the first line does not contain `.venv`, or the second cell fails, open the kernel picker again and choose the `.venv` entry. A global Python, Anaconda, or another project's kernel is a different environment, and it recreates exactly the problem this course teaches you to diagnose.
